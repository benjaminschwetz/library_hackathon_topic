# %% [markdown]
# # Topic Modelling / Clinicaltrials.gov
# ## Import

# %%
#!pip install pyldavis

# %%
import string
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
pd.options.display.max_columns = 50
from tqdm.auto import tqdm
tqdm.pandas()

import textblob

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
nlp = spacy.load('en_core_web_lg')

import pyLDAvis.sklearn

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Create DF

# %%
#articles_df["Abstract"]=articles_df["Abstract"].astype(str)
url = 'https://raw.githubusercontent.com/benjaminschwetz/library_hackathon_topic/master/biofilm2019_scopus.csv'
df = pd.read_csv(url,index_col=0,parse_dates=[0])

# %%
# Creating a vectorizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
NZ_STOP_WORDS = ['biofilm', 'biofilms']
STOP_WORDS = list(ENGLISH_STOP_WORDS) + NZ_STOP_WORDS


#stop_words = {'english' + 'biofilm' + 'biofilms'}
vectorizer = CountVectorizer(min_df=5, max_df=0.9, stop_words=STOP_WORDS, lowercase=True, token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}')
data_vectorized = vectorizer.fit_transform(df['Abstract'])

# %%
NUM_TOPICS = 10

# Latent Dirichlet Allocation Model
lda = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=50, learning_method='online',verbose=True)
data_lda = lda.fit_transform(data_vectorized)
print(data_lda)
# Out:
# iteration: 1 of max_iter: 50
# iteration: 2 of max_iter: 50
# iteration: 3 of max_iter: 50
# iteration: 4 of max_iter: 50
# iteration: 5 of max_iter: 50
# iteration: 6 of max_iter: 50
# iteration: 7 of max_iter: 50
# iteration: 8 of max_iter: 50
# iteration: 9 of max_iter: 50
# iteration: 10 of max_iter: 50
# iteration: 11 of max_iter: 50
# iteration: 12 of max_iter: 50
# iteration: 13 of max_iter: 50
# iteration: 14 of max_iter: 50
# iteration: 15 of max_iter: 50
# iteration: 16 of max_iter: 50
# iteration: 17 of max_iter: 50
# iteration: 18 of max_iter: 50
# iteration: 19 of max_iter: 50
# iteration: 20 of max_iter: 50
# iteration: 21 of max_iter: 50
# iteration: 22 of max_iter: 50
# iteration: 23 of max_iter: 50
# iteration: 24 of max_iter: 50
# iteration: 25 of max_iter: 50
# iteration: 26 of max_iter: 50
# iteration: 27 of max_iter: 50
# iteration: 28 of max_iter: 50
# iteration: 29 of max_iter: 50
# iteration: 30 of max_iter: 50
# iteration: 31 of max_iter: 50
# iteration: 32 of max_iter: 50
# iteration: 33 of max_iter: 50
# iteration: 34 of max_iter: 50
# iteration: 35 of max_iter: 50
# iteration: 36 of max_iter: 50
# iteration: 37 of max_iter: 50
# iteration: 38 of max_iter: 50
# iteration: 39 of max_iter: 50
# iteration: 40 of max_iter: 50
# iteration: 41 of max_iter: 50
# iteration: 42 of max_iter: 50
# iteration: 43 of max_iter: 50
# iteration: 44 of max_iter: 50
# iteration: 45 of max_iter: 50
# iteration: 46 of max_iter: 50
# iteration: 47 of max_iter: 50
# iteration: 48 of max_iter: 50
# iteration: 49 of max_iter: 50
# iteration: 50 of max_iter: 50
# [[1.86768493e-02 7.75430427e-04 6.48521758e-02 ... 7.75335401e-04
#   7.75238886e-04 4.75039048e-01]
#  [1.02072889e-03 1.02050073e-03 1.02048718e-03 ... 1.02054354e-03
#   1.02064681e-03 1.02046766e-03]
#  [2.28716311e-01 1.45077788e-01 2.44067702e-02 ... 1.01023352e-03
#   1.01028259e-03 1.01026550e-03]
#  ...
#  [5.31210156e-01 2.55870284e-02 4.38700175e-04 ... 4.38688061e-04
#   1.73309719e-01 4.38715312e-04]
#  [5.35332122e-01 5.63542368e-02 5.12950898e-04 ... 2.80411159e-02
#   2.10339168e-01 1.46525101e-01]
#  [2.52816389e-02 3.53440912e-04 1.84509408e-01 ... 3.53420236e-04
#   3.53417461e-04 3.53397102e-04]]

# %%
# Function for printing keywords for each topic
test = {}

def selected_topics(model, vectorizer, top_n=20):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
                  

selected_topics(lda, vectorizer)


# from pprint import pprint
# pprint(lda_model.print_topics())
# doc_lda = lda_model[corpus]
vectorizer.get_feature_names()
# Out:
# Topic 0:
# [('isolates', 732.6736724388818), ('strains', 417.5651614362668), ('resistance', 256.8613342366352), ('study', 202.7574453053388), ('genes', 194.5397885431567), ('gene', 164.87560319708152), ('samples', 154.84141599582472), ('patients', 141.35209763857029), ('associated', 138.69387063793621), ('isolated', 135.87480436254063), ('community', 126.60369719768525), ('showed', 122.70461612832534), ('sequencing', 117.58832623744026), ('water', 117.21568885474369), ('resistant', 116.86750548843574), ('results', 115.69278967733709), ('clinical', 115.52582013026334), ('aureus', 105.00800894330786), ('higher', 104.57980129491548), ('high', 103.78072437594957)]
# Topic 1:
# [('aeruginosa', 322.42082626627587), ('infections', 318.6097788687576), ('resistance', 298.5748574713453), ('antibiotic', 275.57247415835064), ('antibiotics', 224.0569036778009), ('infection', 204.61076997147612), ('bacterial', 204.4225719753158), ('bacteria', 195.54122281224662), ('treatment', 165.8980017370086), ('chronic', 143.71941800456403), ('review', 130.1979905954442), ('clinical', 128.46432677800138), ('host', 123.70068929298833), ('pseudomonas', 114.7181871804223), ('phage', 110.47198734140014), ('mechanisms', 106.76956175662188), ('pathogens', 104.05251981738424), ('cells', 102.90176683590302), ('new', 100.56329246119861), ('wounds', 91.29122415487191)]
# Topic 2:
# [('oral', 346.973136975736), ('bacterial', 146.54918151898528), ('gingivalis', 126.79517131139774), ('microbial', 116.27932382267632), ('microbiome', 115.17785926434676), ('species', 113.4381603678906), ('bacteria', 103.07241152102854), ('microbiota', 99.17887403081642), ('interactions', 91.78967822326457), ('caries', 70.79734156934306), ('author', 66.95720952245917), ('disease', 66.87828070645072), ('gut', 66.07984789209766), ('healthy', 58.78463874826138), ('human', 58.602631825041556), ('health', 58.32316272954057), ('cancer', 54.51219468634175), ('streptococcus', 54.38470729215307), ('communities', 53.82868722824756), ('role', 53.768564849432956)]
# Topic 3:
# [('group', 197.21927842092677), ('patients', 174.71696571388742), ('surface', 157.33656980045018), ('groups', 145.16284302160153), ('dental', 135.89847098442118), ('periodontal', 129.0719519132095), ('methods', 123.9718413746463), ('treatment', 119.59521154393896), ('implant', 112.38557549041032), ('bacterial', 105.87164157212807), ('used', 105.82384408796649), ('implants', 101.0582869529991), ('materials', 97.3863510582093), ('tissue', 96.41311422094098), ('results', 95.77034496323877), ('clinical', 95.65368816805206), ('material', 93.91414161109714), ('bone', 92.64702291541153), ('study', 92.40113666180868), ('plaque', 80.262343980081)]
# Topic 4:
# [('microbial', 382.2593474517466), ('surface', 258.9763260321783), ('bacteria', 198.98953162564507), ('carbon', 196.42389339104685), ('study', 182.47050657189337), ('conditions', 164.83045379604025), ('results', 161.5893149825456), ('systems', 159.5829484744069), ('production', 153.93120066263018), ('authors', 153.01090272906887), ('different', 151.96724883463332), ('process', 147.43340811506278), ('used', 145.66536718739562), ('water', 144.23335241288987), ('using', 142.3251279389619), ('removal', 141.72769438425945), ('analysis', 136.07987429711085), ('wastewater', 131.4657557458819), ('high', 123.06087453817113), ('biological', 120.35793997777269)]
# Topic 5:
# [('formation', 507.98028523402115), ('bacteria', 420.8326605804972), ('study', 398.66512670605107), ('growth', 337.1340299469967), ('results', 333.82355033754646), ('bacterial', 305.6417540436885), ('using', 279.0096263186333), ('showed', 257.69653222333665), ('effect', 247.00258939246672), ('significantly', 236.80404808450808), ('water', 219.9857861758091), ('species', 194.94335921164023), ('significant', 187.55909718303178), ('observed', 186.24987458898053), ('used', 185.31794926483653), ('compared', 184.92072271278815), ('microscopy', 180.68489438444658), ('control', 179.56852717502431), ('different', 165.3162680726191), ('strain', 164.3221052187172)]
# Topic 6:
# [('activity', 562.7516826523429), ('antimicrobial', 486.4894457321008), ('aureus', 448.4956571571365), ('antibacterial', 349.19687078735853), ('bacterial', 300.883027774209), ('aeruginosa', 269.55969069334805), ('bacteria', 237.1166992313703), ('staphylococcus', 221.84550962916097), ('showed', 221.50921609147358), ('study', 203.54248903562953), ('concentration', 203.1271949109816), ('potential', 194.5857739723537), ('effect', 189.63612061574455), ('compounds', 188.74988111250087), ('inhibitory', 185.22051623452074), ('nanoparticles', 184.56629461403918), ('mic', 183.99883083188251), ('formation', 179.7420879502073), ('properties', 175.15927489878126), ('using', 168.86521664550796)]
# Topic 7:
# [('albicans', 428.6691372904654), ('virulence', 389.6194644408861), ('candida', 277.95837952458015), ('formation', 252.2655919892892), ('species', 198.09084725158493), ('infections', 165.64085567516798), ('antifungal', 165.14716865713876), ('baumannii', 164.41508545347543), ('infection', 163.6753002328861), ('quorum', 150.7083595441283), ('factors', 147.84149145407457), ('fungal', 140.73154060086875), ('production', 136.01143327542547), ('pathogenic', 125.29744792111956), ('sensing', 115.82623068533384), ('pathogen', 112.01045826836531), ('strains', 106.59497328435496), ('study', 101.98042739659735), ('potential', 101.93545744806421), ('clinical', 94.85842591176242)]
# Topic 8:
# [('mutans', 307.76239717611526), ('original', 241.60722597955925), ('terms', 240.46382602314205), ('use', 239.63093823796865), ('distribution', 232.02701933067496), ('reproduction', 221.26248827427688), ('article', 181.94718867544745), ('distributed', 164.9529404970247), ('license', 159.3441263170704), ('creative', 158.3198954440498), ('commons', 158.31989481076272), ('provided', 155.5573136942776), ('attribution', 153.35122616689515), ('permitted', 151.37011463436318), ('credited', 145.0110594882689), ('copyright', 122.25837054501527), ('author', 114.56350714939337), ('streptococcus', 107.55130807214113), ('faecalis', 95.36853461812818), ('journal', 89.93525361303318)]
# Topic 9:
# [('formation', 421.40940854873367), ('genes', 398.924271039), ('expression', 338.11714117580885), ('proteins', 329.1559291811515), ('protein', 249.55728350460356), ('cell', 246.02722295622087), ('strain', 236.90012637780896), ('cells', 233.7782265787118), ('gene', 214.93114173495897), ('bacterial', 207.82586905938444), ('stress', 192.51052725437333), ('involved', 179.716690468702), ('production', 175.66286173707692), ('role', 169.43394140369304), ('response', 166.76050839545462), ('virulence', 158.76322953747223), ('motility', 157.34773940897415), ('mutant', 154.4818907979386), ('levels', 150.4414162019176), ('type', 148.81931449956912)]
# ['-based',
#  '-day',
#  '-dependent',
#  '-dimethylthiazol-',
#  '-diphenyltetrazolium',
#  '-fold',
#  '-hour',
#  '-hsl',
#  '-lactam',
#  '-lactamase',
#  '-log',
#  '-month',
#  '-phosphate',
#  '-week',
#  '-well',
#  '-year',
#  '-year-old',
#  '-yl',
#  'aap',
#  'abc',
#  'abilities',
#  'ability',
#  'abiotic',
#  'able',
#  'abolished',
#  'absence',
#  'absent',
#  'absolute',
#  'absorbance',
#  'absorbed',
#  'absorption',
#  'abstract',
#  'abundance',
#  'abundances',
#  'abundant',
#  'academic',
#  'academy',
#  'accelerate',
#  'accelerated',
#  'accepted',
#  'acceptor',
#  'access',
#  'accessible',
#  'accession',
#  'accessory',
#  'accompanied',
#  'accordance',
#  'according',
#  'accordingly',
#  'account',
#  'accounted',
#  'accounting',
#  'accumulate',
#  'accumulated',
#  'accumulation',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'acetate',
#  'acetic',
#  'achieve',
#  'achieved',
#  'achieving',
#  'acid',
#  'acidic',
#  'acidithiobacillus',
#  'acidity',
#  'acidobacteria',
#  'acidogenicity',
#  'acids',
#  'acinetobacter',
#  'acnes',
#  'acquired',
#  'acquisition',
#  'acrylic',
#  'act',
#  'acting',
#  'actinobacteria',
#  'actinomyces',
#  'actinomycetemcomitans',
#  'action',
#  'actions',
#  'activate',
#  'activated',
#  'activates',
#  'activating',
#  'activation',
#  'activator',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'acts',
#  'actual',
#  'acute',
#  'acyl',
#  'adapt',
#  'adaptation',
#  'adaptations',
#  'adapted',
#  'adaption',
#  'adaptive',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additive',
#  'additives',
#  'address',
#  'addressed',
#  'addressing',
#  'adenosine',
#  'adequate',
#  'adhere',
#  'adhered',
#  'adherence',
#  'adherent',
#  'adhering',
#  'adhesin',
#  'adhesins',
#  'adhesion',
#  'adhesive',
#  'adhesives',
#  'adjacent',
#  'adjunct',
#  'adjunctive',
#  'adjusted',
#  'administered',
#  'administration',
#  'adolescents',
#  'adopted',
#  'adsorption',
#  'adult',
#  'adults',
#  'advance',
#  'advanced',
#  'advancement',
#  'advances',
#  'advantage',
#  'advantages',
#  'adverse',
#  'adversely',
#  'aerobic',
#  'aerobically',
#  'aeromonas',
#  'aeruginosa',
#  'aesthetic',
#  'affect',
#  'affected',
#  'affecting',
#  'affects',
#  'affinity',
#  'afm',
#  'africa',
#  'african',
#  'agar',
#  'age',
#  'aged',
#  'agent',
#  'agents',
#  'ages',
#  'aggregate',
#  'aggregated',
#  'aggregates',
#  'aggregatibacter',
#  'aggregation',
#  'agnps',
#  'ago',
#  'agr',
#  'agreement',
#  'agricultural',
#  'agriculture',
#  'agrobacterium',
#  'ahl',
#  'ahls',
#  'ai-',
#  'aid',
#  'aim',
#  'aimed',
#  'aiming',
#  'aims',
#  'air',
#  'air-liquid',
#  'airway',
#  'airways',
#  'alarming',
#  'albeit',
#  'albicans',
#  'alcohol',
#  'algae',
#  'algal',
#  'alginate',
#  'alginolyticus',
#  'algorithms',
#  'alkaline',
#  'allele',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'alloy',
#  'alpha',
#  'alphaproteobacteria',
#  'als',
#  'alter',
#  'alteration',
#  'alterations',
#  'altered',
#  'altering',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'alters',
#  'altogether',
#  'aluminum',
#  'alveolar',
#  'alves',
#  'ambient',
#  'amd',
#  'america',
#  'american',
#  'amikacin',
#  'amine',
#  'amino',
#  'aminoglycoside',
#  'aminoglycosides',
#  'ammonia',
#  'ammonium',
#  'amoebae',
#  'amounts',
#  'amoxicillin',
#  'amp',
#  'amphotericin',
#  'ampicillin',
#  'amplicon',
#  'amplification',
#  'amplified',
#  'amps',
#  'amr',
#  'amyloid',
#  'anaerobe',
#  'anaerobic',
#  'anaerobiosis',
#  'analogs',
#  'analogues',
#  'analyse',
#  'analysed',
#  'analyses',
#  'analysis',
#  'analytical',
#  'analyze',
#  'analyzed',
#  'analyzing',
#  'ancestor',
#  'anchoring',
#  'angle',
#  'animal',
#  'animals',
#  'anionic',
#  'ann',
#  'annotated',
#  'annotation',
#  'annually',
#  'anode',
#  'anodes',
#  'anodic',
#  'anova',
#  'anoxic',
#  'answer',
#  'antagonism',
#  'antagonist',
#  'antagonistic',
#  'antagonize',
#  'anterior',
#  'anti-adhesive',
#  'anti-bacterial',
#  'anti-biofilm',
#  'anti-infective',
#  'anti-inflammatory',
#  'anti-microbial',
#  'anti-qs',
#  'anti-quorum',
#  'anti-staphylococcal',
#  'anti-virulence',
#  'antibacterial',
#  'antibiofilm',
#  'antibiotic',
#  'antibiotic-resistant',
#  'antibiotics',
#  'antibodies',
#  'antibody',
#  'anticancer',
#  'anticaries',
#  'anticipated',
#  'antifouling',
#  'antifungal',
#  'antifungals',
#  'antimicrobial',
#  'antimicrobials',
#  'antioxidant',
#  'antioxidants',
#  'antiseptic',
#  'antiseptics',
#  'antiviral',
#  'antivirulence',
#  'aob',
#  'apart',
#  'apical',
#  'apparatus',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appeared',
#  'appears',
#  'appliances',
#  'applicability',
#  'applicable',
#  'application',
#  'applications',
#  'applied',
#  'applying',
#  'approach',
#  'approaches',
#  'appropriate',
#  'approved',
#  'approximately',
#  'aquaculture',
#  'aquatic',
#  'aqueous',
#  'archaea',
#  'archaeal',
#  'architecture',
#  'arcobacter',
#  'arctic',
#  'area',
#  'areas',
#  'arginine',
#  'arise',
#  'arms',
#  'aromatic',
#  'arrangement',
#  'array',
#  'arsenal',
#  'arthritis',
#  'article',
#  'articles',
#  'artificial',
#  'ascribed',
#  'asia',
#  'asked',
#  'aspect',
#  'aspects',
#  'aspergillus',
#  'assay',
#  'assayed',
#  'assays',
#  'assemblages',
#  'assembled',
#  'assembly',
#  'assess',
#  'assessed',
#  'assessing',
#  'assessment',
#  'assessments',
#  'assigned',
#  'assist',
#  'assisted',
#  'associated',
#  'association',
#  'associations',
#  'assumed',
#  'asymptomatic',
#  'atcc',
#  'atmosphere',
#  'atmospheric',
#  'atomic',
#  'atp',
#  'atpase',
#  'attach',
#  'attached',
#  'attachment',
#  'attack',
#  'attempt',
#  'attempts',
#  'attention',
#  'attenuate',
#  'attenuated',
#  'attenuation',
#  'attracted',
#  'attractive',
#  'attributed',
#  'attributes',
#  'attribution',
#  'atypical',
#  'augmentation',
#  'august',
#  'aureus',
#  'auris',
#  'author',
#  'authors',
#  'autoinducer',
#  'autoinducer-',
#  'autoinducers',
#  'automated',
#  'autotrophic',
#  'availability',
#  'available',
#  'avenues',
#  'average',
#  'avian',
#  'avoid',
#  'avoided',
#  'avoiding',
#  'awareness',
#  'away',
#  'azithromycin',
#  'azole',
#  'azoles',
#  'bacilli',
#  'bacillus',
#  'backbone',
#  'background',
#  'bacteremia',
#  'bacteria',
#  'bacterial',
#  'bactericidal',
#  'bacteriocin',
#  'bacteriophage',
#  'bacteriophages',
#  'bacterium',
#  'bacteroides',
#  'bacteroidetes',
#  'balance',
#  'balb',
#  'band',
#  'bands',
#  'bap',
#  'barrier',
#  'basal',
#  'base',
#  'based',
#  'basel',
#  'baseline',
#  'basic',
#  'basis',
#  'batch',
#  'baumannii',
#  'bauru',
#  'bay',
#  'bcr',
#  'beads',
#  'bearing',
#  'bed',
#  'beginning',
#  'behalf',
#  'behavior',
#  'behaviors',
#  'behaviour',
#  'believe',
#  'believed',
#  'belong',
#  'belonged',
#  'belonging',
#  'belongs',
#  'beneficial',
#  'benefit',
#  'benefits',
#  'benthic',
#  'benzalkonium',
#  'bess',
#  'best',
#  'beta',
#  'better',
#  'bhi',
#  'bias',
#  'bile',
#  'bind',
#  'binding',
#  'binds',
#  'bioactive',
#  'bioactivity',
#  'bioavailability',
#  'biocathode',
#  'biochemical',
#  'biocide',
#  'biocides',
#  'biocompatibility',
#  'biocompatible',
#  'biocontrol',
#  'biocorrosion',
#  'biodegradable',
#  'biodegradation',
#  'biodiversity',
#  'bioelectrochemical',
#  'biofilm-associated',
#  'biofilm-forming',
#  'biofilm-like',
#  'biofilm-producing',
#  'biofilm-related',
#  'biofouling',
#  'biofuels',
#  'biogenesis',
#  'biogeochemical',
#  'bioinformatic',
#  'bioinformatics',
#  'bioleaching',
#  'biological',
#  'biologically',
#  'biology',
#  'bioluminescent',
#  'biomarkers',
#  'biomass',
#  'biomaterial',
#  'biomaterials',
#  'biomedical',
#  'biomolecules',
#  'biophysical',
#  'biopolymers',
#  'biopsies',
#  'bioreactor',
#  'bioreactors',
#  'bioremediation',
#  'biosensors',
#  'biosurfactant',
#  'biosurfactants',
#  'biosynthesis',
#  'biosynthesized',
#  'biosynthetic',
#  'biotechnological',
#  'biotechnology',
#  'biotic',
#  'biovolume',
#  'birds',
#  'bla',
#  'black',
#  'bladder',
#  'bleeding',
#  'blight',
#  'block',
#  'blocked',
#  'blocking',
#  'blocks',
#  'blood',
#  'bloodstream',
#  'blot',
#  'blue',
#  'bod',
#  'bodies',
#  'body',
#  'bond',
#  'bonding',
#  'bonds',
#  'bone',
#  'bound',
#  'bovine',
#  'brain',
#  'brasileira',
#  'brazil',
#  'break',
#  'breast',
#  'brief',
#  'briefly',
#  'british',
#  'broad',
#  'broad-spectrum',
#  'broader',
#  'broadly',
#  'bromide',
#  'broth',
#  'brought',
#  'brown',
#  'brush',
#  'brushing',
#  'buffer',
#  'build',
#  'building',
#  'built',
#  'bulk',
#  'burden',
#  'burdens',
#  'burkholderia',
#  'burn',
#  'burst',
#  'by-product',
#  'by-products',
#  'c-di-gmp',
#  'c-terminal',
#  'caco-',
#  'caenorhabditis',
#  'calcium',
#  'calculate',
#  'calculated',
#  'calculations',
#  'called',
#  'calorimetry',
#  'campylobacter',
#  'canal',
#  'canals',
#  'cancer',
#  'candida',
#  'candidate',
#  'candidates',
#  'candidatus',
#  'candidemia',
#  'candidiasis',
#  'canine',
#  'canonical',
#  'cao',
#  'cap',
#  'capabilities',
#  'capability',
#  'capable',
#  'capacities',
#  'capacity',
#  'capsular',
#  'capsule',
#  'capture',
#  'carbapenem-resistant',
#  'carbohydrate',
#  'carbohydrates',
#  'carbon',
#  'carbonate',
#  'carboxyl',
#  'carcinoma',
#  'cardiac',
#  'care',
#  'careful',
#  'carefully',
#  'caries',
#  'cariogenic',
#  'carious',
#  'carriage',
#  'carried',
#  'carrier',
#  'carriers',
#  'carries',
#  'carry',
#  'carrying',
#  'cas',
#  'cascade',
#  'case',
#  'cases',
#  'caspofungin',
#  'cassette',
#  'catalase',
#  'catalyst',
#  'catalytic',
#  'categories',
#  'categorized',
#  'catheter',
#  'catheter-associated',
#  'catheter-related',
#  'catheterization',
#  'catheters',
#  'cathode',
#  'cathodic',
#  'cationic',
#  'cations',
#  'causal',
#  'causative',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'cavity',
#  'cdc',
#  'cdi',
#  'ceftazidime',
#  'cell',
#  'cell-cell',
#  'cell-surface',
#  'cell-to-cell',
#  'cells',
#  'cellular',
#  'cellulose',
#  'center',
#  'centers',
#  'central',
#  'century',
#  'cepacia',
#  'cereus',
#  'cerevisiae',
#  'certain',
#  'cetylpyridinium',
#  'cfu',
#  'chain',
#  'chains',
#  'challenge',
#  'challenged',
#  'challenges',
#  'challenging',
#  'chamber',
#  'chances',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channel',
#  'channels',
#  'chaperone',
#  'character',
#  'characterise',
#  'characterised',
#  'characteristic',
#  'characteristics',
#  'characterization',
#  'characterize',
#  'characterized',
#  'characterizing',
#  'charge',
#  'charged',
#  'charges',
#  'check',
#  'checkerboard',
#  'chemical',
#  'chemically',
#  'chemicals',
#  'chemistry',
#  'chemotaxis',
#  'chemotherapy',
#  'chen',
#  'chicken',
#  'children',
#  'china',
#  'chinese',
#  'chips',
#  'chitin',
#  'chitosan',
#  'chlorhexidine',
#  'chloride',
#  'chlorine',
#  'chlorophyll',
#  'choice',
#  'cholerae',
#  'chosen',
#  'chromatography',
#  'chromatography-mass',
#  'chromobacterium',
#  'chromosome',
#  'chronic',
#  'chx',
#  'ciprofloxacin',
#  'circuit',
#  'circular',
#  'circulating',
#  'circulation',
#  'circumstances',
#  'cited',
#  'citrobacter',
#  'citrus',
#  'city',
#  'clade',
#  'clarified',
#  'clarify',
#  'class',
#  'classes',
#  'classical',
#  'classification',
#  'classified',
#  'clean',
#  'cleaning',
#  'clear',
#  'clearance',
#  'cleared',
#  'clearly',
#  'cleavage',
#  'climate',
#  'clindamycin',
#  'clinic',
#  'clinical',
#  'clinically',
#  'clinicians',
#  'clinics',
#  'cloacae',
#  'clogging',
#  'clonal',
#  'clone',
#  'cloned',
#  'clones',
#  'cloning',
#  'close',
#  'closed',
#  'closely',
#  'clostridioides',
#  'clostridium',
#  'closure',
#  'clp',
#  'clsm',
#  'cluster',
#  'clustered',
#  'clustering',
#  'clusters',
#  'cm-',
#  'cmc',
#  'co-culture',
#  'co-cultured',
#  'co-occurrence',
#  'coagulase',
#  'coagulase-negative',
#  'coastal',
#  'coated',
#  'coating',
#  'coatings',
#  'coculture',
#  'cod',
#  'coding',
#  'coefficient',
#  'coexistence',
#  'cognate',
#  'coherence',
#  'cohort',
#  'cold',
#  'coli',
#  'colistin',
#  'collagen',
#  'collected',
#  'collection',
#  'collective',
#  'collectively',
#  'colon',
#  'colonies',
#  'colonisation',
#  'colonization',
#  'colonize',
#  'colonized',
#  'colonizers',
#  'colonizes',
#  'colonizing',
#  'colony',
#  'colony-forming',
#  'color',
#  'colorectal',
#  'colorimetric',
#  'column',
#  'com',
#  'comamonas',
#  'combat',
#  'combating',
#  'combination',
#  'combinations',
#  'combine',
#  'combined',
#  'combining',
#  'comes',
#  'commensal',
#  'commensals',
#  'commercial',
#  'commercially',
#  'common',
#  'commonly',
#  'commons',
#  'communication',
#  'communities',
#  'community',
#  'community-acquired',
#  'compact',
#  'company',
#  'comparable',
#  'comparative',
#  'comparatively',
#  'compare',
#  'compared',
#  'compares',
#  'comparing',
#  'comparison',
#  'comparisons',
#  'compatible',
#  'compete',
#  'competence',
#  'competition',
#  'competitive',
#  'complement',
#  'complementary',
#  'complementation',
#  'complemented',
#  'complete',
#  'completed',
#  'completely',
#  'complex',
#  'complexes',
#  'complexity',
#  'complicate',
#  'complicated',
#  'complication',
#  'complications',
#  'comply',
#  'component',
#  'components',
#  'composed',
#  'composite',
#  'composites',
#  'composition',
#  'compositional',
#  'compositions',
#  'compound',
#  'compounds',
#  'comprehensive',
#  'comprehensively',
#  'compression',
#  'comprise',
#  'comprised',
#  'comprises',
#  'comprising',
#  'compromised',
#  'computational',
#  'computer',
#  'concentration',
#  'concentration-dependent',
#  'concentrations',
#  'concept',
#  'concepts',
#  'concern',
#  'concerning',
#  'concerns',
#  'conclude',
#  'concluded',
#  'conclusion',
#  'conclusions',
#  'concomitant',
#  'condition',
#  'conditions',
#  'conducted',
#  'conductive',
#  'conductivity',
#  'confer',
#  'conferred',
#  'conferring',
#  'confers',
#  'configuration',
#  'confined',
#  'confirm',
#  'confirmed',
#  'confirming',
#  'confirms',
#  'confocal',
#  'congo',
#  'conjugate',
#  'conjugated',
#  'conjugative',
#  'connected',
#  'connection',
#  'connections',
#  'consecutive',
#  'consensus',
#  'consequence',
#  'consequences',
#  'consequent',
#  'consequently',
#  'conservation',
#  'conserved',
#  'consider',
#  'considerable',
#  'considerably',
#  'consideration',
#  'considered',
#  'considering',
#  'considers',
#  'consist',
#  'consisted',
#  'consistent',
#  'consistently',
#  'consisting',
#  'consists',
#  'consortia',
#  'consortium',
#  'constant',
#  'constantly',
#  'constituent',
#  'constituents',
#  'constitute',
#  'constitutes',
#  'constitutive',
#  'constraints',
#  'construct',
#  'constructed',
#  'construction',
#  'consumed',
#  'consumer',
#  'consumers',
#  'consumption',
#  'contact',
#  'contain',
#  'contained',
#  'containing',
#  'contains',
#  'contaminants',
#  'contaminated',
#  'contamination',
#  'contemporary',
#  'content',
#  'contents',
#  'context',
#  'continue',
#  'continued',
#  'continuous',
#  'continuously',
#  'contracture',
#  ...]

# %%
pyLDAvis.enable_notebook()
dash = pyLDAvis.sklearn.prepare(lda, data_vectorized, vectorizer, mds='tsne')
dash

# %%
# with open(LDAvis_data_filepath, 'w') as f:
#         pickle.dump(LDAvis_prepared, f)
        
# # load the pre-prepared pyLDAvis data from disk
# with open(LDAvis_data_filepath) as f:
#     LDAvis_prepared = pickle.load(f)
# pyLDAvis.save_html(LDAvis_prepared, './ldavis_prepared_'+ str(number_topics) +'.html')

# %%
dash.token_table
#include the article of origin?
